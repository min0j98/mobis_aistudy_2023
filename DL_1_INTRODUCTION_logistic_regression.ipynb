# %% [markdown]
# <a href="https://colab.research.google.com/github/min0j98/mobis_aistudy_2023/blob/master/DL_1_INTRODUCTION_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. 텐서플로에서 실행하는 로지스틱 회귀 모델

# %% [markdown]
# ### 1.환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2. 데이터 준비

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

# %% [markdown]
# ### 3. 모델 실행

# %%
model_1000 = Sequential()
model_1000.add(Dense(1, input_dim=1, activation='sigmoid'))

# 교차 엔트로피 오차 함수를 이용하기 위하여 'binary_crossentropy'로 설정합니다.
model_1000.compile(optimizer='sgd' ,loss='binary_crossentropy')
model_1000.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 281ms/step - loss: 3.5703
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1958
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8281
# Epoch 4/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4696
# Epoch 5/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1247
# Epoch 6/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7991
# Epoch 7/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5015
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2424
# Epoch 9/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0319
# Epoch 10/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8745
# Epoch 11/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7660
# Epoch 12/1000
# ...

# %%
# 그래프로 확인해 봅니다.

plt.scatter(x, y)
plt.plot(x, model_1000.predict(x),'r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 90ms/step

# %%
model_5000 = Sequential()
model_5000.add(Dense(1, input_dim=1, activation='sigmoid'))

# 교차 엔트로피 오차 함수를 이용하기 위하여 'binary_crossentropy'로 설정합니다.
model_5000.compile(optimizer='sgd' ,loss='binary_crossentropy')
model_5000.fit(x, y, epochs=5000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 1431/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3388
# Epoch 1432/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3387
# Epoch 1433/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3386
# Epoch 1434/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3385
# Epoch 1435/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3384
# Epoch 1436/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3383
# Epoch 1437/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3382
# Epoch 1438/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3381
# Epoch 1439/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3380
# Epoch 1440/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3380
# Epoch 1441/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3379
# ...

# %% [markdown]
# ### 4. 모델 테스트

# %%
# 그래프로 확인해 봅니다.

plt.scatter(x, y)
plt.plot(x, model_5000.predict(x),'r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 50ms/step

# %%
# 임의의 학습 시간을 집어넣어 합격 예상 확률을 예측해 보겠습니다.

hour = 7
prediction = model_5000.predict([hour])

print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % (hour, prediction * 100))
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 7시간을 공부할 경우, 합격 예상 확률은 59.8%입니다
